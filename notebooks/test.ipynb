# %%
pt = spark.read.parquet("../parquet_data/playlist_tracks")
print(pt.count())
p = spark.read.parquet("../parquet_data/playllists")
print(p.count())
t = spark.read.parquet("../parquet_data/tracks")
print(t.count())
# Out:
# 66346052
# 999999
# 2262107
